# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
house_df = pd.read_csv("./data/house-price.csv")

# %%
house_df.head()
# Out:
#                  Address   Price  Bedrooms  Bathrooms  Garage  Build Year  \
# 0         1 Datchet Turn  270000         3          2     2.0      2011.0
# 1      1 McKenzie Corner  470000         4          2     2.0      2005.0
# 2  10 Addingham Crescent  455000         4          2     2.0      2004.0
# 3   10 Cleopatra Circuit  410000         4          2     2.0      2005.0
# 4        10 Corrour Bend  245000         3          2     1.0      2012.0
#
#    Floor Area
# 0         109
# 1         279
# 2         200
# 3         148
# 4         105

# %%
house_df.tail()
# Out:
#                   Address   Price  Bedrooms  Bathrooms  Garage  Build Year  \
# 199   9 Kalbarri Crescent  442000         4          2     4.0      2008.0
# 200         9 Kawoor Mews  380000         6          3     2.0      2006.0
# 201  90 Centennial Avenue  376000         4          2     2.0      2008.0
# 202  93 Centennial Avenue  350000         4          2     2.0      2005.0
# 203  98 Centennial Avenue  441000         4          2     2.0      2004.0
#
#      Floor Area
# 199         240
# 200         200
# 201         180
# 202         177
# 203         195

# %%
house_df.dtypes
# Out:
# Address        object
# Price           int64
# Bedrooms        int64
# Bathrooms       int64
# Garage        float64
# Build Year    float64
# Floor Area      int64
# dtype: object

# %%
house_df.shape
# Out:
# (204, 7)

# %%
print(y.shape)
print(X.shape)
# Out:
# (204,)
# (204, 5)

# %%
house_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 204 entries, 0 to 203
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Address     204 non-null    object
#  1   Price       204 non-null    int64
#  2   Bedrooms    204 non-null    int64
#  3   Bathrooms   204 non-null    int64
#  4   Garage      204 non-null    float64
#  5   Build Year  204 non-null    float64
#  6   Floor Area  204 non-null    int64
# dtypes: float64(2), int64(4), object(1)
# memory usage: 11.3+ KB

# %%
y = house_df["Price"]
X = house_df.drop(columns=["Price", "Address"])

# %%
from sklearn.tree import DecisionTreeRegressor
model = DecisionTreeRegressor()
model.fit(X, y)
# Out:
# DecisionTreeRegressor()

# %%
model.score(X, y)
# Out:
# 0.9746449876358452

# %%
import pickle

with open("model.pkl", "wb") as file:
    pickle.dump(model, file)
